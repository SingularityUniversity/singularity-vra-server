# %% [markdown]
# ## Analyze the Results of the Category Extract Notebook
# This notebook takes the two files generated by the Category Graph notebook and calculates some basic graph stats.

# %%
import pickle
import numpy as np
from tqdm import tqdm_notebook
import sys
sys.setrecursionlimit(2000)

# %%
def dfs(G, start, visited=None, depth=0, stats=None):
    if visited is None:
        visited = set()
        stats = {'min':-1, 'max':-1, 'paths':[], 'cycles':0}
    visited.add(start)
    if set(G[start]) - visited == set():
        #terminal_type = 'leaf'
        if G[start] != []:
            stats['cycles'] += 1 
            #terminal_type = 'cycle'
        #print('{}: {} @ {}'.format(terminal_type, start, depth))
        if depth < stats['min'] or stats['min'] == -1:
            stats['min'] = depth
        if depth > stats['max']:
            stats['max'] = depth
        stats['paths'].append(depth)
    for next in set(G[start]) - visited:
        dfs(G, next, visited, depth+1, stats)
    return stats
    
def graph_stats(G, roots):
    '''
    Do DFS and report the min and max depths for each "root"
    '''
    stats = {}
    for root in roots:
        stats[root] = dfs(G, root)
    return stats

# %%
# simple tree
test1 = {
    'a': ['b', 'c'],
    'b': ['d'],
    'c': ['e'],
    'd': [],
    'e': []
}
stats = graph_stats(test1, ['a'])
print(stats)
print('mean: {}  stdev: {}'.format(np.mean(stats['a']['paths']), np.std(stats['a']['paths'])))
# Out:
# {'a': {'max': 2, 'min': 2, 'cycles': 0, 'paths': [2, 2]}}
# mean: 2.0  stdev: 0.0

# %%
# deeper, asymetrical tree
test2 = {
    'a': ['b', 'c'],
    'b': ['d', 'e'],
    'c': ['f', 'g'],
    'd': [],
    'e': ['h'],
    'f': [],
    'g': [],
    'h': []
}
stats = graph_stats(test2, ['a'])
print(stats)
print('mean: {}  stdev: {}'.format(np.mean(stats['a']['paths']), np.std(stats['a']['paths'])))
# Out:
# {'a': {'max': 3, 'min': 2, 'cycles': 0, 'paths': [3, 2, 2, 2]}}
# mean: 2.25  stdev: 0.4330127018922193

# %%
# tree with multiple roots
test3 = {
    'a': ['d', 'c'],
    'b': ['c', 'e'],
    'c': [],
    'd': ['f'],
    'e': ['h'],
    'f': ['g'],
    'g': [],
    'h': []
}
stats = graph_stats(test3, ['a', 'b'])
for root in stats:
    print('*** {} ***'.format(root))
    print(stats[root])
    print('paths: {}'.format(len(stats[root]['paths'])))
    print('mean: {}  stdev: {}'.format(np.mean(stats[root]['paths']), 
                                       np.std(stats[root]['paths'])))
print('total paths: {}'.format(sum([len(stats[root]['paths']) for root in stats])))
# Out:
# *** b ***
# {'max': 2, 'min': 1, 'cycles': 0, 'paths': [2, 1]}
# paths: 2
# mean: 1.5  stdev: 0.5
# *** a ***
# {'max': 3, 'min': 1, 'cycles': 0, 'paths': [3, 1]}
# paths: 2
# mean: 2.0  stdev: 1.0
# total paths: 4

# %%
# graph with cycle
test4 = {
    'a': ['b', 'c'],
    'b': ['d'],
    'c': ['e'],
    'd': [],
    'e': ['a']
}
stats = graph_stats(test4, ['a'])
print(stats)
print('mean: {}  stdev: {}'.format(np.mean(stats['a']['paths']), np.std(stats['a']['paths'])))
# Out:
# {'a': {'max': 2, 'min': 2, 'cycles': 1, 'paths': [2, 2]}}
# mean: 2.0  stdev: 0.0

# %%
with open('../data/ontology/readable_graph.p', 'rb') as fp:
    readable_graph = pickle.load(fp)
with open('../data/ontology/readable_roots.p', 'rb') as fp:
    readable_roots = pickle.load(fp)

# %%
stats = graph_stats(readable_graph, readable_roots)
for stat in tqdm_notebook(stats):
    print('{}: min={} max={} cycles={} paths={} mean={:.2f} stdev={:.2f}'.format(
        stat,
        stats[stat]['min'],
        stats[stat]['max'],  
        stats[stat]['cycles'],
        len(stats[stat]['paths']),
        np.mean(stats[stat]['paths']),
        np.std(stats[stat]['paths'])))
# Out:
# education: min=1 max=1438 cycles=8096 paths=632829 mean=1006.25 stdev=410.19
# rights: min=1 max=1458 cycles=8259 paths=632779 mean=1010.24 stdev=422.94
# hunger: min=1 max=1459 cycles=8162 paths=632690 mean=1001.81 stdev=429.25
# space: min=1 max=1413 cycles=8054 paths=631576 mean=979.26 stdev=409.49
# energy: min=1 max=1409 cycles=8125 paths=631122 mean=979.31 stdev=405.89
# prevention: min=1 max=1417 cycles=8142 paths=632226 mean=974.81 stdev=412.66
# aid: min=1 max=1397 cycles=8044 paths=631882 mean=979.38 stdev=395.38
# biotechnology: min=1 max=1441 cycles=8311 paths=632608 mean=989.50 stdev=410.80
# bioinformatics: min=1 max=1385 cycles=8015 paths=631482 mean=984.20 stdev=399.42
# biological engineering: min=1 max=1440 cycles=8025 paths=632214 mean=989.50 stdev=427.60
# justice: min=1 max=1384 cycles=8122 paths=632251 mean=973.50 stdev=393.04
# political philosphy: min=0 max=0 cycles=0 paths=1 mean=0.00 stdev=0.00
# environmental economics: min=1 max=1429 cycles=8136 paths=632113 mean=973.78 stdev=412.17
# emergency services: min=1 max=1428 cycles=8136 paths=632325 mean=998.66 stdev=404.27
# governance: min=1 max=1423 cycles=8112 paths=632397 mean=997.31 stdev=413.69
# farms: min=1 max=1408 cycles=8094 paths=631974 mean=982.90 stdev=400.17
# accountability: min=1 max=1409 cycles=8056 paths=631718 mean=989.60 stdev=407.55
# individualism: min=1 max=1411 cycles=8132 paths=632290 mean=992.04 stdev=415.03
# nanotechnology: min=1 max=1431 cycles=8099 paths=631806 mean=994.20 stdev=415.20
# robotics: min=1 max=1456 cycles=8212 paths=632533 mean=996.49 stdev=419.41
# telecommunications: min=1 max=1433 cycles=8152 paths=632274 mean=996.73 stdev=416.50
# health: min=1 max=1385 cycles=8114 paths=631866 mean=978.07 stdev=404.55
# habitat: min=1 max=1418 cycles=8179 paths=632171 mean=992.67 stdev=415.07
# land management: min=1 max=1384 cycles=7955 paths=630959 mean=965.36 stdev=395.91
# computers: min=1 max=1479 cycles=8207 paths=632544 mean=999.15 stdev=427.99
# development economics: min=1 max=1424 cycles=8171 paths=633024 mean=984.87 stdev=417.85
# computational biology: min=1 max=1448 cycles=8058 paths=632512 mean=997.21 stdev=433.50
# poverty: min=1 max=1423 cycles=8170 paths=633016 mean=983.95 stdev=417.76
# networks: min=1 max=1441 cycles=8157 paths=632769 mean=1002.67 stdev=409.93
# artificial intelligence: min=1 max=1461 cycles=8091 paths=632362 mean=1001.75 stdev=415.61
# ecosystems: min=1 max=1402 cycles=8136 paths=631513 mean=984.93 stdev=409.08
# ethical principles: min=1 max=1385 cycles=8127 paths=632275 mean=974.23 stdev=393.08
# water: min=1 max=1401 cycles=8053 paths=631914 mean=981.38 stdev=396.54
# earth system sciences: min=1 max=2 cycles=0 paths=15 mean=1.20 stdev=0.40
# environment: min=1 max=1384 cycles=7960 paths=631641 mean=962.99 stdev=386.74
# identity politics: min=1 max=1459 cycles=8115 paths=632089 mean=1011.98 stdev=415.69
# security: min=1 max=1388 cycles=8099 paths=631847 mean=960.33 stdev=401.59
# learning: min=1 max=1430 cycles=8123 paths=632341 mean=1012.24 stdev=422.70

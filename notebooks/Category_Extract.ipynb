# %% [markdown]
# ## Ontology Creation Using Wikipedia Categories
# This notebook assumes that it can connect to a mysql database that has the category, page, and categorylinks tables from wikipedia.  See https://dumps.wikimedia.org/enwiki/latest/.  This is about 50GB of data in mysql (roughly 150 million rows).  To load the data, I had to put the mysql data files in a ramdisk and then move them to a drive after the load was complete.
#
# This notebook extracts all of the subcategories and pages that are linked to the initially specified set of categories to the specified depth.  A depth of 4 results in roughly 600k total nodes in the graph.

# %%
import re
import MySQLdb
from tqdm import tnrange, tqdm_notebook
import pickle
import time
import random

db = MySQLdb.connect(user='root', passwd='abc123', host='127.0.0.1', db='wiki')
c = db.cursor()

DEPTH = 4
category_graph = {}
next_nodes = []

new_nodes = [b'Artificial_intelligence', b'Nanotechnology', b'Robotics', b'Biotechnology',
             b'Networks', b'Bioinformatics', b'Biological_engineering', b'Computational_biology',
             b'Telecommunications', b'Energy', b'Ecosystems', b'Environmental_economics',
             b'Habitat', b'Earth_system_sciences', b'Environment', b'Computers', b'Learning',
             b'Education', b'Water', b'Space', b'Health', b'Poverty', b'Aid', b'Hunger',
             b'Development_economics', b'Farms', b'Land_management', b'Prevention', b'Security',
             b'Emergency_services', b'Political_philosphy', b'Governance', b'Accountability',
             b'Justice', b'Ethical_principles', b'Rights', b'Identity_politics', b'Individualism'
            ]

# %%
def wiki_canonicalize(category):
    # replace spaces with underscore, lowercase, and uppercase first character
    if category[:2] == b'\xce\xa3':
        category = category[2:]
    return category.replace(b' ', b'_').lower().capitalize() 

def human_canonicalize(category):
    if type(category) == bytes:
        return category.replace(b'_', b' ').lower().decode('utf-8')
    else:
        return category.replace('_', ' ').lower()

# %%
readable_roots = [human_canonicalize(root) for root in new_nodes]

with open('readable_roots.p', 'wb') as fp:
    pickle.dump(readable_roots, fp)

# %%
i=0
for current_depth in tqdm_notebook(range(DEPTH), desc='Categories'):
    for category in tqdm_notebook(new_nodes, desc='Subcategories', leave=False):
        if category.endswith(b'_stub') or category.endswith(b'_stubs'):
            continue
        if category not in category_graph:
            category_graph[category] = []
        c.execute('''
           select cl_type, count(*) from categorylinks
           where cl_to = %s group by cl_type
        ''', (category,))
        # apply some filtering if there are too many subcategories or pages.  The theory
        # is that anything with that many subcategories or pages won't be useful in the context
        # of the ontology we're building
        count_dict = {}
        for row in c.fetchall():
            count_dict[row[0]] = row[1]
        too_many_pages = count_dict.get(b'page', 0) > 250
        too_many_subcats = count_dict.get(b'subcat', 0) > 100
        if too_many_pages and too_many_subcats:
            print('skip (all): {}'.format(category), flush=True)
            continue
        where_clause = ''
        if too_many_pages:
            where_clause += ' and cl_type != "page"'
            print('skip (pages): {}'.format(category), flush=True)
        if too_many_subcats:
            where_clause += ' and cl_type != "subcat"'
            print('skip (subcat): {}'.format(category), flush=True)
        c.execute('''
           select cl_sortkey, cl_type from categorylinks
           where cl_to = %s and cl_type != "file" {}
        '''.format(where_clause), (category,))
        for row in c.fetchall():
            # rows can have multiple values separated by \n
            for subcat_or_page in row[0].strip().split(b'\n'):
                subcat_or_page = wiki_canonicalize(subcat_or_page)
                if subcat_or_page.endswith(b'_stub') or subcat_or_page.endswith(b'_stubs'):
                    continue
                if subcat_or_page not in category_graph[category] and \
                        subcat_or_page != category:
                    category_graph[category].append(subcat_or_page)
                if row[1] == b'page' and subcat_or_page not in category_graph:
                    category_graph[subcat_or_page] = []
                if row[1] == b'subcat' and subcat_or_page not in new_nodes and \
                        subcat_or_page not in category_graph and \
                        subcat_or_page not in next_nodes:
                    next_nodes.append(subcat_or_page)
    # replace the content of new_nodes with the content of next_nodes so that the loop will continue to iterate
    final_subcats = next_nodes
    for item in new_nodes:
        new_nodes.remove(item)
    for item in next_nodes:
        new_nodes.append(item)
    next_nodes = []
    
for subcat in final_subcats:
    category_graph[subcat] = []
    
readable_graph = {}
for category in category_graph:
    readable_graph[human_canonicalize(category)] = \
            [human_canonicalize(subcat) for subcat in category_graph[category]]
with open('readable_graph.p', 'wb') as fp:
    pickle.dump(readable_graph, fp)
# Out:
# skip (pages): b'Artificial_intelligence'
# skip (pages): b'Biotechnology'
# skip (pages): b'Bioinformatics'
# skip (pages): b'Biotechnology'
# skip (pages): b'Bioinformatics'
# skip (pages): b'Human\xe2\x80\x93computer_interaction'
# skip (pages): b'Artificial_intelligence_researchers'
# skip (pages): b'Life_sciences_industry'
# skip (pages): b'Biological_databases'
# skip (subcat): b'Telecommunications_by_country'
# skip (pages): b'Computer_networking'
# skip (subcat): b'Energy_by_country'
# skip (subcat): b'Environment_by_year'
# skip (pages): b'Ecology'
# skip (pages): b'Management'
# skip (pages): b'Urban_studies_and_planning'
# skip (pages): b'Psychology'
# skip (pages): b'Educational_psychology'
# skip (subcat): b'Water_by_country'
# skip (pages): b'Hydrology'
# skip (subcat): b'Health_by_country'
# skip (pages): b'Biotechnology'
# skip (pages): b'Human\xe2\x80\x93computer_interaction'
# skip (subcat): b'Telecommunications_by_country'
# skip (pages): b'Educational_psychology'
# skip (subcat): b'Health_by_country'
# skip (subcat): b'Conferences_by_year'
# skip (subcat): b'Fiction_by_nationality'
# skip (subcat): b'Fiction_by_topic'
# skip (pages): b'Virtual_reality'
# skip (subcat): b'Publications_by_year_of_disestablishment'
# skip (subcat): b'Years'
# skip (pages): b'Lists_of_lists'
# skip (subcat): b'Lists_by_country'
# skip (pages): b'Set_indices'
# skip (pages): b'Mecha_anime_and_manga'
# skip (pages): b'Project_management'
# skip (pages): b'Sports_by_year'
# skip (pages): b'Titles'
# skip (pages): b'Transcription_factors'
# skip (pages): b'Gene_expression'
# skip (pages): b'Antibiotics'
# skip (pages): b'Social_networking_services'
# skip (pages): b'Online_databases'
# skip (subcat): b'Engineers_by_nationality'
# skip (subcat): b'Telecommunications_companies_by_country'
# skip (pages): b'Computer_network_security'
# skip (pages): b'Wireless_networking'
# skip (pages): b'Economics_terminology'
# skip (subcat): b'Educators_by_nationality'
# skip (pages): b'Lecturers'
# skip (pages): b'Medical_equipment'
# skip (subcat): b'Cultural_infrastructure_by_year_of_completion'
# skip (subcat): b'Infrastructure_by_country'
# skip (subcat): b'Infrastructure_by_year_of_completion'
# skip (pages): b'Telephone_numbers_by_country'
# skip (pages): b'Standards_organizations'
# skip (subcat): b'Electric_power_by_country'
# skip (subcat): b'Energy_infrastructure_by_country'
# skip (subcat): b'Energy_infrastructure_by_year_of_completion'
# skip (pages): b'Materials_science'
# skip (pages): b'Building_materials'
# skip (subcat): b'Transport_by_country'
# skip (subcat): b'Wikipedia_categories_named_after_forests'
# skip (pages): b'Real_estate'
# skip (subcat): b'Conservation_by_country'
# skip (subcat): b'Environment_by_country'
# skip (subcat): b'Awards_by_country'
# skip (subcat): b'Awards_by_year'
# skip (subcat): b'Awards_by_year_of_establishment'
# skip (subcat): b'Wikipedia_categories_named_after_awards'
# skip (pages): b'Rhetoric'
# skip (pages): b'Internet_search_engines'
# skip (pages): b'Pseudoscience'
# skip (subcat): b'Society_by_nationality'
# skip (pages): b'Legal_terms'
# skip (pages): b'Medical_terminology'
# skip (pages): b'Nautical_terms'
# skip (pages): b'Political_terminology'
# skip (pages): b'Television_terminology'
# skip (pages): b'Urban_public_parks'
# skip (subcat): b'Architecture_by_country'
# skip (all): b'Architectural_styles'
# skip (pages): b'Architectural_elements'
# skip (pages): b'Smartphones'
# skip (pages): b'Payment_systems'
# skip (subcat): b'Education_by_country'
# skip (subcat): b'Education_lists_by_country'
# skip (subcat): b'Academia_by_country'
# skip (subcat): b'Educational_institutions_by_year_of_disestablishment'
# skip (subcat): b'Literature_by_nationality'
# skip (subcat): b'Literature_by_women'
# skip (pages): b'Internet_memes'
# skip (pages): b'Chemistry_set_index_pages'
# skip (pages): b'Oceanography'
# skip (subcat): b'Parks_by_country'
# skip (pages): b'Deaths_by_drowning'
# skip (pages): b'Political_theories'
# skip (subcat): b'Water_transport_by_country'
# skip (pages): b'Algebraic_geometry'
# skip (pages): b'Differential_geometry'
# skip (pages): b'Topologists'
# skip (subcat): b'Activists_by_issue'
# skip (subcat): b'Activists_by_nationality'
# skip (pages): b'Pediatrics'
# skip (pages): b'Syndromes'
# skip (pages): b'Rare_diseases'
# skip (subcat): b'Medical_and_health_organizations_by_country'
# skip (pages): b'People_in_public_health'
# skip (pages): b'Development_charities'
# skip (pages): b'Humanitarian_aid_organizations'
# skip (subcat): b'Museums_by_country'
# skip (subcat): b'Museums_by_type'
# skip (subcat): b'Museums_by_year_of_establishment'
# skip (subcat): b'Wikipedia_categories_named_after_museums'
# skip (subcat): b'Agriculture_by_country'
# skip (subcat): b'Ministries_by_country'
# skip (subcat): b'Ministries_by_year_of_establishment'
# skip (pages): b'People_associated_with_computer_security'
# skip (subcat): b'Prisons_by_country'
# skip (pages): b'Operas'
# skip (subcat): b'Elections_by_country'
# skip (pages): b'National_liberation_movements'
# skip (pages): b'Human_rights_abuses'
# skip (pages): b'Pejorative_terms_for_people'
# skip (subcat): b'Human_rights_by_country'
# skip (pages): b'Human_rights_organizations'
# skip (pages): b'Anti-apartheid_activists'
# skip (subcat): b'Nationalisms'
# skip (subcat): b'Nationalists'
# skip (pages): b'Human\xe2\x80\x93computer_interaction'
# skip (subcat): b'Fiction_by_nationality'
# skip (subcat): b'Fiction_by_topic'
# skip (pages): b'Set_indices'
# skip (pages): b'Mecha_anime_and_manga'
# skip (pages): b'Sports_by_year'
# skip (pages): b'Transcription_factors'
# skip (pages): b'Social_networking_services'
# skip (pages): b'Online_databases'
# skip (subcat): b'Engineers_by_nationality'
# skip (pages): b'Economics_terminology'
# skip (subcat): b'Educators_by_nationality'
# skip (pages): b'Lecturers'
# skip (pages): b'Medical_equipment'
# skip (subcat): b'Infrastructure_by_country'
# skip (pages): b'Telephone_numbers_by_country'
# skip (pages): b'Standards_organizations'
# skip (subcat): b'Energy_infrastructure_by_country'
# skip (pages): b'Building_materials'
# skip (subcat): b'Conservation_by_country'
# skip (subcat): b'Awards_by_country'
# skip (subcat): b'Awards_by_year'
# skip (subcat): b'Awards_by_year_of_establishment'
# skip (subcat): b'Wikipedia_categories_named_after_awards'
# skip (pages): b'Television_terminology'
# skip (pages): b'Urban_public_parks'
# skip (subcat): b'Architecture_by_country'
# skip (all): b'Architectural_styles'
# skip (pages): b'Architectural_elements'
# skip (pages): b'Smartphones'
# skip (subcat): b'Academia_by_country'
# skip (subcat): b'Literature_by_nationality'
# skip (subcat): b'Parks_by_country'
# skip (pages): b'Deaths_by_drowning'
# skip (pages): b'Political_theories'
# skip (pages): b'Algebraic_geometry'
# skip (pages): b'Differential_geometry'
# skip (pages): b'Rare_diseases'
# skip (subcat): b'Medical_and_health_organizations_by_country'
# skip (pages): b'People_in_public_health'
# skip (subcat): b'Museums_by_year_of_establishment'
# skip (subcat): b'Wikipedia_categories_named_after_museums'
# skip (subcat): b'Agriculture_by_country'
# skip (subcat): b'Ministries_by_country'
# skip (subcat): b'Ministries_by_year_of_establishment'
# skip (pages): b'People_associated_with_computer_security'
# skip (subcat): b'Prisons_by_country'
# skip (pages): b'National_liberation_movements'
# skip (pages): b'Pejorative_terms_for_people'
# skip (pages): b'Anti-apartheid_activists'
# skip (subcat): b'Nationalisms'
# skip (subcat): b'Nationalists'
# skip (pages): b'Virtual_communities'
# skip (subcat): b'Cycling_by_country'
# skip (pages): b'Stubs'
# skip (pages): b'Post-apocalyptic_video_games'
# skip (pages): b'Shapeshifting_in_fiction'
# skip (subcat): b'Books_by_publisher'
# skip (subcat): b'Magazines_by_country'
# skip (subcat): b'Magazines_by_year_of_establishment'
# skip (pages): b'Comics_publications'
# skip (subcat): b'Short_stories_by_writer'
# skip (pages): b'Novellas'
# skip (subcat): b'Writers_by_award'
# skip (subcat): b'Writers_by_language'
# skip (subcat): b'Writers_by_nationality'
# skip (pages): b'Marxist_writers'
# skip (pages): b'Pseudonymous_writers'
# skip (pages): b'Abstract_strategy_games'
# skip (subcat): b'Media_people_by_nationality'
# skip (pages): b'Publications_with_year_of_establishment_missing'
# skip (pages): b'Days_of_the_year'
# skip (pages): b'Online_periodicals_with_defunct_print_editions'
# skip (pages): b'Series_of_books'
# skip (pages): b'Epidemiologists'
# skip (pages): b'Unmanned_aerial_vehicles'
# skip (subcat): b'History_by_country'
# skip (subcat): b'History_by_country_and_topic'
# skip (subcat): b'Historians_by_nationality'
# skip (pages): b'Japanese_eras'
# skip (pages): b'Concepts_in_physics'
# skip (pages): b'Legal_doctrines_and_principles'
# skip (pages): b'Fictional_cyborgs'
# skip (subcat): b'Events_by_country'
# skip (subcat): b'Festivals_by_type'
# skip (subcat): b'Disestablishments_by_country'
# skip (subcat): b'Establishments_by_country'
# skip (subcat): b'Recurring_events_by_year_of_establishment'
# skip (subcat): b'Protests_by_country'
# skip (pages): b'Protest_songs'
# skip (pages): b'All_set_index_articles'
# skip (pages): b'Airport_disambiguation'
# skip (pages): b'Set_indices_on_comics'
# skip (pages): b'Enzyme_set_index_pages'
# skip (pages): b'Greek_mythology'
# skip (pages): b'Lists_of_roads_sharing_the_same_title'
# skip (pages): b'Set_indices_on_ships'
# skip (subcat): b'Lists_of_buildings_and_structures_by_country'
# skip (subcat): b'Geography-related_lists_by_country'
# skip (pages): b'Lists_of_airline_destinations'
# skip (pages): b'Lists_of_coordinates'
# skip (subcat): b'Politics-related_lists_by_country'
# skip (pages): b'Mathematics-related_lists'
# skip (subcat): b'Sports-related_lists_by_country'
# skip (subcat): b'Organizations_by_country'
# skip (subcat): b'Lists_of_organizations_by_country'
# skip (subcat): b'Government_by_country'
# skip (subcat): b'Musicians_by_band'
# skip (subcat): b'People_by_company'
# skip (subcat): b'Wikipedia_categories_named_after_courts'
# skip (subcat): b'Wikipedia_categories_named_after_fraternal_service_organizations'
# skip (subcat): b'Wikipedia_categories_named_after_government_agencies'
# skip (subcat): b'Wikipedia_categories_named_after_military_units_and_formations'
# skip (subcat): b'Wikipedia_categories_named_after_political_organizations'
# skip (subcat): b'Wikipedia_categories_named_after_religious_organizations'
# skip (subcat): b'Wikipedia_categories_named_after_schools'
# skip (subcat): b'Wikipedia_categories_named_after_universities_and_colleges'
# skip (subcat): b'Buildings_and_structures_by_type'
# skip (subcat): b'Language_families'
# skip (subcat): b'Video_games_by_company'
# skip (pages): b'Cross-platform_software'
# skip (pages): b'Android_(operating_system)_software'
# skip (pages): b'Business_software'
# skip (pages): b'Web_applications'
# skip (pages): b'Production_and_manufacturing'
# skip (pages): b'Software_testing'
# skip (subcat): b'Sports_competitions_by_sport'
# skip (subcat): b'Sports_competitors_by_sport'
# skip (subcat): b'Sport_by_country_and_sport'
# skip (subcat): b'Sports_by_country_and_year'
# skip (subcat): b'Sports_organisations_by_year_of_establishment'
# skip (subcat): b'Sports_venues_by_year_of_completion'
# skip (pages): b'Business_terms'
# skip (pages): b'Plagiarism_controversies'
# skip (subcat): b'Wikipedia_categories_named_after_sports_events'
# skip (subcat): b'Festivals_by_year_of_establishment'
# skip (subcat): b'Festivals_by_year'
# skip (subcat): b'Festivals_by_country'
# skip (subcat): b'People_by_occupation'
# skip (pages): b'Occupational_surnames'
# skip (subcat): b'Sports_venues_by_country'
# skip (subcat): b'Law_by_country'
# skip (subcat): b'Communications_by_country'
# skip (pages): b'Living_people'
# skip (pages): b'Missing_people'
# skip (pages): b'Possibly_living_people'
# skip (subcat): b'Films_by_studio'
# skip (subcat): b'Singles_by_record_label'
# skip (subcat): b'Television_series_by_studio'
# skip (subcat): b'Albums_by_record_label'
# skip (subcat): b'Aircraft_by_manufacturer'
# skip (subcat): b'Producers_by_nationality'
# skip (pages): b'Military_brats'
# skip (subcat): b'Zoos_by_year_of_establishment'
# skip (pages): b'Given_names'
# skip (subcat): b'People_by_ethnicity'
# skip (subcat): b'Academics_by_nationality'
# skip (subcat): b'Archaeological_sites_by_country'
# skip (subcat): b'Forts_by_country'
# skip (subcat): b'Houses_by_year_of_completion'
# skip (subcat): b'Houses_by_country'
# skip (pages): b'Kibbutzim'
# skip (pages): b'Moshavim'
# skip (subcat): b'Palaces_by_country'
# skip (subcat): b'Families_by_nationality'
# skip (pages): b'Married_couples'
# skip (pages): b'Network_protocols'
# skip (pages): b'Online_companies'
# skip (pages): b'Commerce_websites'
# skip (pages): b'Economics_books'
# skip (pages): b'Art_curators'
# skip (pages): b'Measuring_instruments'
# skip (subcat): b'Internet_by_country'
# skip (pages): b'Touchscreen_mobile_phones'
# skip (subcat): b'Radio_by_country'
# skip (subcat): b'Television_by_country'
# skip (pages): b'Television_technology'
# skip (subcat): b'Dams_by_country'
# skip (subcat): b'Dams_by_year_of_completion'
# skip (subcat): b'Government_buildings_by_country'
# skip (subcat): b'Government_buildings_by_year_of_completion'
# skip (subcat): b'Transport_infrastructure_by_year_of_completion'
# skip (subcat): b'Lighthouses_by_year_of_completion'
# skip (subcat): b'Power_stations_by_country'
# skip (subcat): b'Renewable_energy_by_country'
# skip (subcat): b'Hydroelectricity_by_country'
# skip (subcat): b'Energy_companies_by_country'
# skip (subcat): b'Power_companies_by_country'
# skip (subcat): b'Electric_power_infrastructure_by_country'
# skip (pages): b'Condensed_matter_physics'
# skip (pages): b'Optics'
# skip (subcat): b'Case_law_by_year'
# skip (subcat): b'Fossil_fuels_by_country'
# skip (pages): b'Film_and_video_technology'
# skip (pages): b'Women_in_technology'
# skip (subcat): b'Science_and_technology_by_country'
# skip (pages): b'Technical_universities_and_colleges'
# skip (subcat): b'Heads_of_state_by_country'
# skip (pages): b'Children_of_national_leaders'
# skip (subcat): b'Heads_of_state_of_former_countries'
# skip (subcat): b'Orders_of_knighthood_awarded_to_heads_of_state,_consorts_and_sovereign_family_members'
# skip (subcat): b'Spouses_of_national_leaders'
# skip (subcat): b'Transport-related_lists_by_country'
# skip (pages): b'Incomplete_transport_lists'
# skip (subcat): b'Petroleum_by_country'
# skip (subcat): b'Documentary_films_by_country'
# skip (subcat): b'Documentary_films_by_director'
# skip (subcat): b'Protected_areas_by_year_of_establishment'
# skip (pages): b'Drought-tolerant_plants'
# skip (subcat): b'Orders,_decorations,_and_medals_by_country'
# skip (pages): b'Internet_protocols'
# skip (pages): b'Data_management'
# skip (subcat): b'Designers_by_nationality'
# skip (pages): b'Garden_plants'
# skip (subcat): b'Disasters_by_country'
# skip (subcat): b'Disasters_by_year'
# skip (subcat): b'Fires_by_year'
# skip (subcat): b'Natural_disasters_by_country'
# skip (subcat): b'Biota_by_country'
# skip (pages): b'Poisonous_plants'
# skip (subcat): b'Water_supply_and_sanitation_by_country'
# skip (subcat): b'Entertainment_by_country'
# skip (subcat): b'Media_franchises'
# skip (pages): b'History_of_medicine'
# skip (subcat): b'Mining_by_country'
# skip (pages): b'Information_technology_management'
# skip (pages): b'Calcium_minerals'
# skip (pages): b'Iron_minerals'
# skip (subcat): b'Research_institutes_by_country'
# skip (subcat): b'Natural_history_by_country'
# skip (pages): b'Neuroscience'
# skip (pages): b'Women_scientists'
# skip (subcat): b'Scientists_by_nationality'
# skip (pages): b'Fictional_scientists'
# skip (subcat): b'Wikipedia_categories_named_after_scientists'
# skip (subcat): b'Social_history_by_country'
# skip (subcat): b'Bilateral_relations'
# skip (pages): b'International_trade'
# skip (subcat): b'Mass_media_by_language'
# skip (pages): b'Social_psychology'
# skip (pages): b'Sociological_terminology'
# skip (subcat): b'Crime_by_country'
# skip (subcat): b'Songs_by_artist'
# skip (subcat): b'Songs_by_composer'
# skip (subcat): b'Songs_by_country'
# skip (subcat): b'Songs_by_lyricist'
# skip (subcat): b'Song_recordings_by_producer'
# skip (subcat): b'Songs_by_songwriter'
# skip (pages): b'Redirects_from_songs'
# skip (pages): b'Buddhist_terminology'
# skip (pages): b'Christian_terminology'
# skip (pages): b'Articles_which_contain_graphical_timelines'
# skip (pages): b'Film_characters'
# skip (pages): b'Film_genres'
# skip (pages): b'Incest_in_film'
# skip (subcat): b'Schools_by_country'
# skip (subcat): b'Squares_and_plazas_by_city'
# skip (subcat): b'Architects_by_nationality'
# skip (subcat): b'Years_in_architecture'
# skip (pages): b'Audio_podcasts'
# skip (pages): b'Ethology'
# skip (subcat): b'Art_by_nationality'
# skip (pages): b'International_relations_scholars'
# skip (subcat): b'Libraries_by_year_of_establishment'
# skip (pages): b'Muslim_scholars'
# skip (pages): b'Peace_organizations'
# skip (pages): b'International_nongovernmental_organizations'
# skip (pages): b'Sustainability_advocates'
# skip (pages): b'Educational_institutions_with_year_of_establishment_missing'
# skip (subcat): b'Years_in_education'
# skip (pages): b'Japanese_culture'
# skip (subcat): b'Treaties_by_country'
# skip (subcat): b'Treaties_by_year'
# skip (pages): b'Popes'
# skip (pages): b'Medieval_literature'
# skip (subcat): b'Comics_by_writer'
# skip (subcat): b'Plays_by_writer'
# skip (subcat): b'Poetry_by_writer'
# skip (subcat): b'Screenplays_by_writer'
# skip (pages): b'Works_published_under_a_pseudonym'
# skip (pages): b'Films_based_on_novels'
# skip (pages): b'Films_based_on_plays'
# skip (pages): b'Films_based_on_short_fiction'
# skip (pages): b'Years_in_literature'
# skip (pages): b'Incomplete_literature_lists'
# skip (pages): b'Literature_featuring_anthropomorphic_characters'
# skip (pages): b'Nonlinear_narrative_films'
# skip (pages): b'Video_game_publishers'
# skip (pages): b'Film_series'
# skip (pages): b'Novel_series'
# skip (pages): b'Multilingual_films'
# skip (pages): b"Films_based_on_children's_books"
# skip (subcat): b'Wikipedia_categories_named_after_novels'
# skip (pages): b'Arcade_games'
# skip (subcat): b'Libraries_by_country'
# skip (pages): b'Cultural_depictions_of_people'
# skip (pages): b'Viral_videos'
# skip (pages): b'Mobile_games'
# skip (pages): b'Video_games_with_expansion_packs'
# skip (pages): b'Video_game_franchises'
# skip (subcat): b'Ramsar_sites_by_country'
# skip (pages): b'Freshwater_plants'
# skip (pages): b'Lichens'
# skip (pages): b'Penicillium'
# skip (pages): b'Flowers'
# skip (pages): b'Invasive_plant_species'
# skip (pages): b'Medicinal_plants'
# skip (pages): b'Plant_morphology'
# skip (subcat): b'Swimming_by_country'
# skip (pages): b'Molecular_formula_set_index_pages'
# skip (pages): b'Spectroscopy'
# skip (pages): b'Molecular_biology'
# skip (pages): b'Molecular_formulas'
# skip (subcat): b'Chemical_elements'
# skip (subcat): b'Wetlands_by_country'
# skip (subcat): b'Islands_by_country'
# skip (subcat): b'Island_countries'
# skip (subcat): b'Wikipedia_categories_named_after_islands'
# skip (subcat): b'Lakes_by_country'
# skip (subcat): b'Rivers_by_country'
# skip (subcat): b'Wikipedia_categories_named_after_rivers'
# skip (subcat): b'Canals_by_year_of_opening'
# skip (subcat): b'Politics_by_country'
# skip (subcat): b'Politics_by_year'
# skip (subcat): b'Political_history_by_country'
# skip (pages): b'Former_principalities'
# skip (pages): b'Former_republics'
# skip (pages): b'Entheogens'
# skip (subcat): b'Military_by_country'
# skip (subcat): b'Years_in_aquatics'
# skip (pages): b'Cruise_ships'
# skip (subcat): b'Pipelines_by_country'
# skip (all): b'Submarine_classes'
# skip (subcat): b'Astronomical_objects_by_year_of_discovery'
# skip (subcat): b'Discoveries_by_astronomer'
# skip (subcat): b'Countries_in_fiction'
# skip (pages): b'Outlines_of_countries'
# skip (subcat): b'Works_about_countries'
# skip (subcat): b'Wikipedia_categories_named_after_countries'
# skip (pages): b'Redirects_from_personal_names'
# skip (subcat): b'People_by_nationality'
# skip (subcat): b'Constellations'
# skip (subcat): b'Tourist_attractions_by_country'
# skip (subcat): b'Brands_by_company'
# skip (subcat): b'Brands_by_country'
# skip (pages): b'Luxury_brands'
# skip (subcat): b'Death_by_country'
# skip (pages): b'Ships_lost_with_all_hands'
# skip (pages): b'American_women_activists'
# skip (subcat): b'People_with_disabilities_by_nationality'
# skip (pages): b'People_with_bipolar_disorder'
# skip (pages): b'Medical_signs'
# skip (pages): b'Epidermal_nevi,_neoplasms,_cysts'
# skip (subcat): b'Disease-related_deaths_by_country'
# skip (subcat): b'Television_series_by_country'
# skip (pages): b'Television_series_revived_after_cancellation'
# skip (pages): b'Films_based_on_television_series'
# skip (pages): b'Television_spin-offs'
# skip (pages): b'Upcoming_television_series'
# skip (subcat): b'Hospitals_by_country'
# skip (subcat): b'Hospitals_by_year_of_establishment'
# skip (pages): b'Deaths_from_prostate_cancer'
# skip (pages): b'Social_reformers'
# skip (subcat): b'Political_movements_by_country'
# skip (pages): b'Proteins'
# skip (subcat): b'Physicians_by_nationality'
# skip (subcat): b'Economists_by_nationality'
# skip (pages): b'Fictional_physicians'
# skip (subcat): b'Suicides_by_country'
# skip (subcat): b'Journalists_by_nationality'
# skip (pages): b'Male_journalists'
# skip (subcat): b'Newspapers_by_country'
# skip (subcat): b'Art_museums_and_galleries_by_country'
# skip (pages): b'Agricultural_pest_insects'
# skip (subcat): b'Labor_by_country'
# skip (subcat): b'Tunnels_by_year_of_completion'
# skip (subcat): b'Israeli_people_by_occupation'
# skip (pages): b'Landscape_artists'
# skip (subcat): b'Government_ministers_by_country'
# skip (pages): b'Fictional_secret_agents_and_spies'
# skip (subcat): b'Terrorism_by_country'
# skip (subcat): b'Men_by_nationality'
# skip (pages): b'Masculine_given_names'
# skip (subcat): b'Ships_by_country'
# skip (subcat): b'Ships_by_navy'
# skip (pages): b'Individual_sailing_vessels'
# skip (pages): b'Ship_types'
# skip (subcat): b'Women_by_country'
# skip (subcat): b'Women_by_nationality'
# skip (subcat): b'Women_by_occupation'
# skip (pages): b'Feminine_given_names'
# skip (pages): b'Airliner_accidents_and_incidents_caused_by_pilot_error'
# skip (subcat): b'Mass_murder_by_year'
# skip (subcat): b'Law_enforcement_by_country'
# skip (pages): b'Fictional_police_officers'
# skip (subcat): b'Aviation_by_country'
# skip (subcat): b'Years_in_aviation'
# skip (subcat): b'Operas_by_composer'
# skip (pages): b'One-act_operas'
# skip (pages): b'Chief_operating_officers'
# skip (pages): b'Non-partisan_elections'
# skip (pages): b'One-party_elections'
# skip (subcat): b'Constituencies_by_year_of_disestablishment'
# skip (subcat): b'Constituencies_by_year_of_establishment'
# skip (subcat): b'Political_parties_by_country'
# skip (subcat): b'Wikipedia_categories_named_after_political_parties'
# skip (subcat): b'Political_party_alliances_by_country'
# skip (subcat): b'Republics'
# skip (subcat): b'Referendums_by_year'
# skip (pages): b'Prison_films'
# skip (pages): b'Adultery_in_films'
# skip (pages): b'Animal_rights_advocates'
# skip (pages): b'American_civil_rights_activists'
# skip (subcat): b'Lawyers_by_nationality'
# skip (subcat): b'Feminists_by_nationality'
# skip (pages): b'Feminist_artists'
# skip (pages): b'Jewish_socialists'
# skip (subcat): b'Politicians_by_nationality'
# skip (subcat): b'People_by_ethnic_or_national_descent'
# skip (subcat): b'People_by_ethnic_or_national_origin'
# skip (subcat): b'National_symbols_by_nation'
# skip (pages): b'National_anthems'
# skip (subcat): b'Massacres_by_country'

# %%
print(len(category_graph))
# Out:
# 617752

# %%
node_name = b'Artificial_intelligence'
print(node_name)
for i in range(100):
    if category_graph[node_name] == []:
        break
    node_name = category_graph[node_name][random.randint(0, len(category_graph[node_name])-1)]
    print('{}: {}'.format(i, node_name))
# Out:
# b'Artificial_intelligence'
# 0: b'Logic_programming'
# 1: b'Scientific_community_metaphor'
